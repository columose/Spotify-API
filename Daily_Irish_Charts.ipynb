# %% [markdown]
# <a href="https://colab.research.google.com/github/columose/Spotify-API/blob/main/Daily_Irish_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# Import libraries
import pandas_gbq

# Import user data for secret credentials
from google.colab import userdata

SPOTIPY_CLIENT_ID = userdata.get('CLIENT_ID')
SPOTIPY_CLIENT_SECRET = userdata.get('CLIENT_SECRET')

# %%
# Copy functions module to /content and import its functions
# !cp /content/drive/MyDrive/Colab\ Notebooks/Spotify\ API/functions.py /content
from functions import playlist_to_df

# %%
# Extract relevant info from playlist to dataframe

Irish_top_50_url = 'https://open.spotify.com/playlist/37i9dQZEVXbKM896FDX8L1?si=61985adbdf8f4f0d'
df = playlist_to_df(Irish_top_50_url, SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET)
df.head()
# Out:
#      artist_name                                 song_name  popularity  \
# 0   Benson Boone                          Beautiful Things         100
# 1     Noah Kahan                              Stick Season          95
# 2            Djo                          End of Beginning          97
# 3  Ariana Grande  we can't be friends (wait for your love)          93
# 4        Beyoncé                            TEXAS HOLD 'EM          86
#
#                   genres  danceability  energy  key  loudness  mode  \
# 0  singer-songwriter pop         0.472   0.471   10    -5.692     1
# 1             pov: indie         0.662   0.488    9    -6.894     1
# 2             pov: indie         0.689   0.454    2    -7.643     1
# 3                    pop         0.645   0.663    5    -8.305     1
# 4                    pop         0.725   0.709    2    -6.514     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
# Save df to google big query

# Project and table id refer to those from GBQ
project_id = 'spotify-28'
table_id = 'Spotify.Dublin_top_50'

pandas_gbq.to_gbq(df, table_id, project_id=project_id, if_exists = 'replace') # solely for the daily playlist
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 5957.82it/s]
